# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import numpy as np

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0,100,10))

# %%
s.plot()

# %%
df = pd.DataFrame(np.random.randn(100,4).cumsum(0),
                 columns=['a','b','c','d'],
                 index=np.arange(0,100,1))

# %%
df.plot(figsize=(10,5))

# %%
df.plot.bar(figsize=(20,5),width=3)

# %%
df.plot.barh(stacked=False, alpha=0.5,figsize=(5,10),width=3)

# %% [markdown]
# ### Histograms and Density Plots

# %%
import seaborn as sns

# %%
tips = pd.read_csv('a.csv',sep='\s+')
tips
# Out:
#             A         B         C
# aaa -0.264438 -1.026059 -0.619500
# bbb  0.927272  0.302904 -0.032399
# ccc -0.264273 -0.386314 -0.217601
# ddd -0.871858 -0.348382  1.100491

# %%
tips['A'].plot.hist()

# %%
comp1 = np.random.rand(100)
comp2 = np.random.normal(10,2,size=200)

# %%
values = pd.Series(np.concatenate([comp1,comp2]))

# %%
sns.distplot(values, bins=100, color='k')
